# %%
pip install image_slicer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.2 MB 8.4 MB/s
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
cd ..
# Out:
# /content

# %%
# !unzip train_data.zip
# Out:
# Archive:  train_data.zip
#    creating: train_data/images/
#    creating: train_data/images/train/
#   inflating: train_data/images/train/f35bb11.jpg
#   inflating: train_data/images/train/f35bb38.jpg
#   inflating: train_data/images/train/f35cb30.jpg
#   inflating: train_data/images/train/f35cb70.jpg
#   inflating: train_data/images/train/f35db21.jpg
#   inflating: train_data/images/train/f35db23.jpg
#   inflating: train_data/images/train/f35db53.jpg
#   inflating: train_data/images/train/f35eb13.jpg
#   inflating: train_data/images/train/f35eb65.jpg
#   inflating: train_data/images/train/f45bb07.jpg
#   inflating: train_data/images/train/f45eb67.jpg
#   inflating: train_data/images/train/f55bc01.jpg
#   inflating: train_data/images/train/f55bc06.jpg
#   inflating: train_data/images/train/f55bc08.jpg
#   inflating: train_data/images/train/f55bc09.jpg
#   inflating: train_data/images/train/f55bc12.jpg
#   inflating: train_data/images/train/f55bc13.jpg
# ...

# %%
cd dd19/PNG
# Out:
# /content/dd19/PNG

# %%
pwd
# Out:
# '/content'

# %%
cd rt
# Out:
# /content/rt

# %%
import os
from image_slicer import slice
for file in os.listdir("/content/rt"):
    if file.endswith(".png"):
        slice(file,4)

# %%
for file in os.listdir("/content/dd19/PNG"): #iterate through all items in directory
    if len(file) == 11:
        os.remove(file)

# %%
cd ..
# Out:
# /content

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp/weights/best.pt  --img 4032 --conf 0.2 --iou 0.2 --source rt/sub3t.0002_01_01.png  --hide-labels --line-thickness 1 --agnostic-nms
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=rt/sub3t.0002_01_01.png, data=yolov5/data/coco128.yaml, imgsz=[4032, 4032], conf_thres=0.2, iou_thres=0.2, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=True, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=1, hide_labels=True, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients
# image 1/1 /content/rt/sub3t.0002_01_01.png: 4032x4032 1734 tri_juns, 110 quad_juns, Done. (0.206s)
# Speed: 15.2ms pre-process, 206.1ms inference, 12.8ms NMS per image at shape (1, 3, 4032, 4032)
# Results saved to yolov5/runs/detect/exp11

# %%
pwd
# Out:
# '/content/yolov5'

# %%
cd ..
# Out:
# /content

# %%
# !zip -r /content/ppt.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/labels.jpg (deflated 17%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/PR_curve.png (deflated 27%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1655802600.60c81fa6f979.221.0 (deflated 45%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 42%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 19%)
#   adding: content/yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/val_batch1_labels.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 38%)
# ...

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 4 --epochs 200 --data custom.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-258-g1156a32 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
